# %%
# Nếu chạy trong Jupyter, thêm project root vào sys.path
import sys, os, logging

# CHỈNH cho đúng với máy bạn:
PROJECT_ROOT = r"E:\Job\Kin-Hotel\DE\KinHotelAutoDashboard"
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# Log mức INFO cho gọn
logging.getLogger().setLevel("INFO")

# %%
import asyncio

# Nếu notebook báo "event loop is running", bạn có thể dùng "await func()" thay vì asyncio.run(func()).
# Hoặc cài nest_asyncio: pip install nest_asyncio
# import nest_asyncio; nest_asyncio.apply()

# %%
from datetime import datetime, timedelta, timezone

from src.data_pipeline.extractors.pms.booking import BookingListExtractor
from src.utils.date_params import DateWindow, ICT

async def smoke_test_bookings(
    branch_ids=None,
    hours=24,
    limit=15,                 # để ép phân trang nếu dữ liệu nhiều
    field="check_in",         # "check_in" hoặc "create"
    max_concurrent=3
):
    """
    Extract bookings từ PMS cho nhiều branch song song trong khoảng {hours} giờ gần nhất.
    - Không transform, không load
    - In ra số record và 1-2 record mẫu
    """
    ex = BookingListExtractor()

    end_utc = datetime.now(timezone.utc)
    start_utc = end_utc - timedelta(hours=hours)

    # Khung thời gian chuẩn hoá → PMS params (DateWindow sẽ format theo ICT)
    dw_template = DateWindow.from_utc(start_utc, end_utc, field=field, tz=ICT)

    # Nếu không truyền, lấy toàn bộ branch có trong map
    if branch_ids is None:
        branch_ids = list(BookingListExtractor.TOKEN_BRANCH_MAP.keys())

    sem = asyncio.Semaphore(max_concurrent)

    async def run_one(bid: int):
        async with sem:
            # Tạo DateWindow riêng cho branch (tránh mutate)
            dw = DateWindow(start=dw_template.start, end=dw_template.end, field=field, tz=ICT)
            # Gọi extract_async trực tiếp, truyền limit để dễ thấy phân trang
            res = await ex.extract_async(branch_id=bid, date_window=dw, limit=limit)
            return bid, res

    results = await asyncio.gather(*[run_one(b) for b in branch_ids], return_exceptions=True)

    # Đóng session HTTP
    await ex.close()

    # Tổng kết
    ok = 0
    total = 0
    for item in results:
        if isinstance(item, Exception):
            print("Branch task error:", item)
            continue
        bid, res = item
        total += 1
        name = BookingListExtractor.TOKEN_BRANCH_MAP.get(bid, f"Branch {bid}")
        if res.is_success:
            ok += 1
            print(f"[OK] {name} (id={bid}) → {res.record_count} records")
            if res.record_count:
                # In thử 1-2 record đầu cho biết schema
                print("  sample:", res.data[:2])
        else:
            print(f"[FAIL] {name} (id={bid}) → {res.error}")

    print(f"\nDONE: {ok}/{total} branches OK")

# %%
# Ví dụ chạy 3 branch cho nhanh
test_branches = [1, 2,3,4,5, 6,7,,9,10]   # đổi theo nhu cầu

# Nếu cell hỗ trợ await:
await smoke_test_bookings(
    branch_ids=test_branches,
    hours=24,
    limit=15,
    field="check_in",      # hoặc "create" nếu muốn test theo ngày tạo
    max_concurrent=2
)

# Nếu không thể dùng await, thử:
# asyncio.run(smoke_test_bookings(branch_ids=test_branches, hours=24, limit=15, field="check_in", max_concurrent=2))
# Out:
# [2025-08-31 16:47:19] [env_utils.py] [INFO] 🔍 Checking environment variables...
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ ALGORITHM: HS256 [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ ODOO_PASSWORD: ***HIDDEN*** [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ EMAIL_SENDER: thanh... [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ ODOO_EMAIL: thanh... [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ ODOO_URL: https... [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ PMS_PASSWORD: ***HIDDEN*** [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ EMAIL_PASSWORD: ***HIDDEN*** [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ MAX_WORKERS: 5 [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ EMAIL_RECIPIENT: thanh... [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ RETRY_LIMIT: 3 [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ PMS_BASE_URL: https... [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ RETRY_DELAY: 5 [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ PMS_EMAIL: thanh... [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ GDRIVE_FOLDER_ID: 0AGwu... [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] ✅ SECRET_KEY: w78Lw... [PASS]
# [2025-08-31 16:47:19] [env_utils.py] [INFO] 🎉 All environment variables are valid!
# [2025-08-31 16:47:19] [token_manager.py] [INFO] 🔄 Using cached pms token
# [2025-08-31 16:47:19] [pms_extractor.py] [INFO] 🔧 Extracted base token from: eyJhbGciOiJIUzI1NiIs...
# [2025-08-31 16:47:19] [pms_extractor.py] [INFO] 🔑 Branch 1 token: eyJhbGciOiJIUzI1NiIs...
# [2025-08-31 16:47:19] [booking.py] [INFO] 🚀 Starting extraction bookings:check_in for KIN HOTEL DONG DU: 2025-08-30 16:47:19 → 2025-08-31 16:47:19
# [2025-08-31 16:47:19] [booking.py] [INFO] 🔍 Fetching page 1 …
# [2025-08-31 16:47:19] [pms_extractor.py] [INFO] 🔑 Branch 2 token: eyJhbGciOiJIUzI1NiIs...
# [2025-08-31 16:47:19] [booking.py] [INFO] 🚀 Starting extraction bookings:check_in for KIN HOTEL THI SACH EDITION: 2025-08-30 16:47:19 → 2025-08-31 16:47:19
# [2025-08-31 16:47:19] [booking.py] [INFO] 🔍 Fetching page 1 …
# [2025-08-31 16:47:19] [booking.py] [INFO] 🔍 Sleep Fetching page 1 in 5s…
# [2025-08-31 16:47:24] [booking.py] [INFO] 🔍 Sleep Fetching page 1 in 5s…
# [2025-08-31 16:47:29] [booking.py] [INFO] ✅ Final page detected (got 5 < limit 15).
# [2025-08-31 16:47:29] [booking.py] [INFO] ✅ PMS KIN HOTEL THI SACH EDITION: Extracted 5 records in 10.32s
# [2025-08-31 16:47:29] [pms_extractor.py] [INFO] 🔑 Branch 3 token: eyJhbGciOiJIUzI1NiIs...
# [2025-08-31 16:47:29] [booking.py] [INFO] 🚀 Starting extraction bookings:check_in for KIN HOTEL THAI VAN LUNG: 2025-08-30 16:47:19 → 2025-08-31 16:47:19
# [2025-08-31 16:47:29] [booking.py] [INFO] 🔍 Fetching page 1 …
# [2025-08-31 16:47:29] [booking.py] [INFO] 🔍 Fetching page 2 …
# [2025-08-31 16:47:29] [pms_extractor.py] [ERROR] Permission error 403 for https://api-pms.kinliving.vn/api/bookings params={'check_in_from': '2025-08-30 16:47:19', 'check_in_to': '2025-08-31 16:47:19', 'limit': 15, 'page': 2} body=<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>403 Forbidden</title>
# <h1>Forbidden</h1>
# <p>Access Denied</p>
#
# [2025-08-31 16:47:29] [booking.py] [ERROR] ❌ PMS KIN HOTEL DONG DU failed after 10.39s: HTTP 403 for https://api-pms.kinliving.vn/api/bookings
# [2025-08-31 16:47:29] [pms_extractor.py] [INFO] 🔑 Branch 4 token: eyJhbGciOiJIUzI1NiIs...
# [2025-08-31 16:47:29] [booking.py] [INFO] 🚀 Starting extraction bookings:check_in for KIN WANDER TAN BINH, THE MOUNTAIN: 2025-08-30 16:47:19 → 2025-08-31 16:47:19
# [2025-08-31 16:47:29] [booking.py] [INFO] 🔍 Fetching page 1 …
# [2025-08-31 16:47:30] [booking.py] [INFO] 🔍 Sleep Fetching page 1 in 5s…
# [2025-08-31 16:47:35] [booking.py] [INFO] ✅ Final page detected (got 4 < limit 15).
# [2025-08-31 16:47:35] [booking.py] [INFO] ✅ PMS KIN WANDER TAN BINH, THE MOUNTAIN: Extracted 4 records in 5.24s
# [2025-08-31 16:47:35] [pms_extractor.py] [INFO] 🔑 Branch 5 token: eyJhbGciOiJIUzI1NiIs...
# [2025-08-31 16:47:35] [booking.py] [INFO] 🚀 Starting extraction bookings:check_in for KIN WANDER TAN QUY: 2025-08-30 16:47:19 → 2025-08-31 16:47:19
# [2025-08-31 16:47:35] [booking.py] [INFO] 🔍 Fetching page 1 …
# [2025-08-31 16:47:35] [booking.py] [INFO] 🔍 Sleep Fetching page 1 in 5s…
# [2025-08-31 16:47:40] [booking.py] [INFO] 🔍 Sleep Fetching page 1 in 5s…
# [2025-08-31 16:47:45] [booking.py] [INFO] ✅ No more records. Pagination complete.
# [2025-08-31 16:47:45] [booking.py] [INFO] ✅ PMS KIN WANDER TAN QUY: Extracted 0 records in 10.20s
# [2025-08-31 16:47:45] [pms_extractor.py] [INFO] 🔑 Branch 6 token: eyJhbGciOiJIUzI1NiIs...
# [2025-08-31 16:47:45] [booking.py] [INFO] 🚀 Starting extraction bookings:check_in for KIN WANDER TAN PHONG, THE MOONAGE: 2025-08-30 16:47:19 → 2025-08-31 16:47:19
# [2025-08-31 16:47:45] [booking.py] [INFO] 🔍 Fetching page 1 …
# [2025-08-31 16:47:45] [booking.py] [INFO] 🔍 Fetching page 2 …
# [2025-08-31 16:47:45] [pms_extractor.py] [ERROR] Permission error 403 for https://api-pms.kinliving.vn/api/bookings params={'check_in_from': '2025-08-30 16:47:19', 'check_in_to': '2025-08-31 16:47:19', 'limit': 15, 'page': 2} body=<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>403 Forbidden</title>
# <h1>Forbidden</h1>
# <p>Access Denied</p>
#
# [2025-08-31 16:47:45] [booking.py] [ERROR] ❌ PMS KIN HOTEL THAI VAN LUNG failed after 15.58s: HTTP 403 for https://api-pms.kinliving.vn/api/bookings
# [2025-08-31 16:47:45] [pms_extractor.py] [INFO] 🔑 Branch 7 token: eyJhbGciOiJIUzI1NiIs...
# [2025-08-31 16:47:45] [booking.py] [INFO] 🚀 Starting extraction bookings:check_in for KIN WANDER TRUNG SON: 2025-08-30 16:47:19 → 2025-08-31 16:47:19
# [2025-08-31 16:47:45] [booking.py] [INFO] 🔍 Fetching page 1 …
# [2025-08-31 16:47:45] [booking.py] [INFO] 🔍 Sleep Fetching page 1 in 5s…
# [2025-08-31 16:47:50] [booking.py] [INFO] ✅ Final page detected (got 13 < limit 15).
# [2025-08-31 16:47:50] [booking.py] [INFO] ✅ PMS KIN WANDER TAN PHONG, THE MOONAGE: Extracted 13 records in 5.29s
# [2025-08-31 16:47:50] [pms_extractor.py] [INFO] 🔑 Branch 8 token: eyJhbGciOiJIUzI1NiIs...
# [2025-08-31 16:47:50] [booking.py] [INFO] 🚀 Starting extraction bookings:check_in for Branch 8: 2025-08-30 16:47:19 → 2025-08-31 16:47:19
# [2025-08-31 16:47:50] [booking.py] [INFO] 🔍 Fetching page 1 …
# [2025-08-31 16:47:50] [booking.py] [INFO] 🔍 Sleep Fetching page 1 in 5s…
# [2025-08-31 16:47:55] [booking.py] [INFO] ✅ Final page detected (got 3 < limit 15).
# [2025-08-31 16:47:55] [booking.py] [INFO] ✅ PMS KIN WANDER TRUNG SON: Extracted 3 records in 10.24s
# [2025-08-31 16:47:55] [pms_extractor.py] [INFO] 🔑 Branch 9 token: eyJhbGciOiJIUzI1NiIs...
# [2025-08-31 16:47:55] [booking.py] [INFO] 🚀 Starting extraction bookings:check_in for KIN HOTEL CENTRAL PARK: 2025-08-30 16:47:19 → 2025-08-31 16:47:19
# [2025-08-31 16:47:55] [booking.py] [INFO] 🔍 Fetching page 1 …
# [2025-08-31 16:47:55] [pms_extractor.py] [ERROR] Permission error 401 for https://api-pms.kinliving.vn/api/bookings params={'check_in_from': '2025-08-30 16:47:19', 'check_in_to': '2025-08-31 16:47:19', 'limit': 15, 'page': 1} body={"code": "ACCESS_ERROR", "error": "Current user is not allowed to access this branch"}
# [2025-08-31 16:47:55] [booking.py] [ERROR] ❌ PMS Branch 8 failed after 5.20s: HTTP 401 for https://api-pms.kinliving.vn/api/bookings
# [2025-08-31 16:47:55] [pms_extractor.py] [INFO] 🔑 Branch 10 token: eyJhbGciOiJIUzI1NiIs...
# [2025-08-31 16:47:55] [booking.py] [INFO] 🚀 Starting extraction bookings:check_in for KIN HOTEL LY TU TRONG: 2025-08-30 16:47:19 → 2025-08-31 16:47:19
# [2025-08-31 16:47:55] [booking.py] [INFO] 🔍 Fetching page 1 …
# [2025-08-31 16:47:55] [booking.py] [INFO] 🔍 Sleep Fetching page 1 in 5s…
# [2025-08-31 16:48:00] [booking.py] [INFO] ✅ Final page detected (got 9 < limit 15).
# [2025-08-31 16:48:00] [booking.py] [INFO] ✅ PMS KIN HOTEL CENTRAL PARK: Extracted 9 records in 5.26s
# [2025-08-31 16:48:01] [booking.py] [INFO] 🔍 Sleep Fetching page 1 in 5s…
# [2025-08-31 16:48:07] [booking.py] [INFO] 🔍 Fetching page 2 …
# [2025-08-31 16:48:07] [pms_extractor.py] [ERROR] Permission error 403 for https://api-pms.kinliving.vn/api/bookings params={'check_in_from': '2025-08-30 16:47:19', 'check_in_to': '2025-08-31 16:47:19', 'limit': 15, 'page': 2} body=<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>403 Forbidden</title>
# <h1>Forbidden</h1>
# <p>Access Denied</p>
#
# [2025-08-31 16:48:07] [booking.py] [ERROR] ❌ PMS KIN HOTEL LY TU TRONG failed after 11.85s: HTTP 403 for https://api-pms.kinliving.vn/api/bookings
# [2025-08-31 16:48:07] [pms_extractor.py] [INFO] 🧹 Closing all network sessions...
# [2025-08-31 16:48:07] [pms_extractor.py] [INFO] 🔒 All sessions closed.
# [FAIL] KIN HOTEL DONG DU (id=1) → HTTP 403 for https://api-pms.kinliving.vn/api/bookings
# [OK] KIN HOTEL THI SACH EDITION (id=2) → 5 records
#   sample: [{'booking_line_id': 43216, 'booking_line_sequence_id': 'BL40865', 'check_in_date': '2025-08-31', 'check_out_date': '2025-09-01', 'room_id': 7529, 'room_name': 'PRM-D (702)', 'room_type_id': 7558, 'room_type_name': 'PRM-D', 'original_room_type_name': 'DLX-D', 'display_room_type_name': 'Premium Double With Window', 'attributes': {'room_no': '702'}, 'price': 2064480.0, 'booking_days': 1, 'paid_amount': 0.0, 'pricelist': {'id': 9, 'name': 'OTA'}, 'sale_order_name': None, 'adult': 2, 'child': 1, 'subtotal_price': 2064480.0, 'total_price': 2064480.0, 'cancel_price': 0.0, 'cancel_reason': False, 'balance': 0.0, 'remain_amount': 2064480.0, 'check_in': '2025-08-31 07:00:00', 'actual_check_in': '2025-08-31 07:25:37', 'check_out': '2025-09-01 05:00:00', 'actual_check_out': False, 'status': 'allot', 'note': 'DLX-D >> PRM-D (FOC), BF, RCTA, OTHER POA\nINCLUDED CHILD AGED 6', 'booking_id': 33467, 'booking_sequence_id': 'B32338', 'partner_id': 70235, 'partner_name': 'DAI XINJIAN', 'gender': 'male', 'booking_line_guest_ids': [60973, 61457, 61458], 'medium_id': 46, 'medium_name': 'Trip.Com', 'source_id': 18, 'source_name': 'SO - OTA', 'campaign_id': None, 'campaign_name': None, 'cms_booking_id': 'TR4589175638287401', 'cms_ota_id': '1128142138597514', 'cms_booking_source': 'TRCO', 'partner_identification': 'EH6355809', 'group_master_name': None, 'labels': [], 'hotel_travel_agency_name': 'Trip.Com', 'hotel_travel_agency_id': 63, 'create_date': '2025-08-28 12:07:56', 'group_id': 70235, 'group_master': None, 'room_status': {'is_clean': True, 'is_occupied': True}, 'surveys': {'is_checkin': False, 'is_checkout': False}, 'is_foc': False, 'reason_approve_by': False, 'foc_level': False, 'cancelled_at': False, 'room_no': '702', 'pricelist_id': 9, 'pricelist_name': 'OTA', 'room_is_clean': True, 'room_is_occupied': True, 'survey_is_checkin': False, 'survey_is_checkout': False}, {'booking_line_id': 41726, 'booking_line_sequence_id': 'BL39375', 'check_in_date': '2025-08-31', 'check_out_date': '2025-09-01', 'room_id': 7573, 'room_name': 'KFS (1104)', 'room_type_id': 7560, 'room_type_name': 'KFS', 'original_room_type_name': 'DLX-T', 'display_room_type_name': 'Kin Family Suit', 'attributes': {'room_no': '1104'}, 'price': 2129760.0, 'booking_days': 1, 'paid_amount': 0.0, 'pricelist': {'id': 9, 'name': 'OTA'}, 'sale_order_name': None, 'adult': 1, 'child': 0, 'subtotal_price': 2129760.0, 'total_price': 3529760.0, 'cancel_price': 0.0, 'cancel_reason': False, 'balance': 0.0, 'remain_amount': 2129760.0, 'check_in': '2025-08-31 07:00:00', 'actual_check_in': False, 'check_out': '2025-09-01 05:00:00', 'actual_check_out': False, 'status': 'initial', 'note': '1 DLX-T >> KFS (FOC), BF, ALL-POA\nFUG: AVOID NOISE\nP/U 31/8 EK392 - 20:00 (PAID)\nD/O 1/9 VJ343 - CF D/O TIME UPCI (PAID)\nETA 9:00 PM - 10:00 PM\nXIN GOOD REVIEW (NẾU ĐƯỢC)', 'booking_id': 32321, 'booking_sequence_id': 'B31192', 'partner_id': 68108, 'partner_name': 'Sarah-Jane Smith', 'gender': 'male', 'booking_line_guest_ids': [58684], 'medium_id': 18, 'medium_name': 'Booking.com', 'source_id': 18, 'source_name': 'SO - OTA', 'campaign_id': None, 'campaign_name': None, 'cms_booking_id': 'BOB2631755503438N3202', 'cms_ota_id': '5446990052', 'cms_booking_source': 'BDC', 'partner_identification': False, 'group_master_name': None, 'labels': [], 'hotel_travel_agency_name': 'Booking.com', 'hotel_travel_agency_id': 5, 'create_date': '2025-08-18 07:50:40', 'group_id': 68108, 'group_master': None, 'room_status': {'is_clean': True, 'is_occupied': False}, 'surveys': {'is_checkin': False, 'is_checkout': False}, 'is_foc': False, 'reason_approve_by': False, 'foc_level': False, 'cancelled_at': False, 'room_no': '1104', 'pricelist_id': 9, 'pricelist_name': 'OTA', 'room_is_clean': True, 'room_is_occupied': False, 'survey_is_checkin': False, 'survey_is_checkout': False}]
# [FAIL] KIN HOTEL THAI VAN LUNG (id=3) → HTTP 403 for https://api-pms.kinliving.vn/api/bookings
# [OK] KIN WANDER TAN BINH, THE MOUNTAIN (id=4) → 4 records
#   sample: [{'booking_line_id': 43505, 'booking_line_sequence_id': 'BL41154', 'check_in_date': '2025-08-31', 'check_out_date': '2025-09-01', 'room_id': 9163, 'room_name': 'S.STD (202)', 'room_type_id': 9019, 'room_type_name': 'S.STD', 'original_room_type_name': 'S.STD', 'display_room_type_name': 'Super Standard', 'attributes': {'room_no': '202'}, 'price': 939675.0, 'booking_days': 1, 'paid_amount': 0.0, 'pricelist': {'id': 9, 'name': 'OTA'}, 'sale_order_name': None, 'adult': 1, 'child': 0, 'subtotal_price': 939675.0, 'total_price': 939675.0, 'cancel_price': 0.0, 'cancel_reason': False, 'balance': 0.0, 'remain_amount': 939675.0, 'check_in': '2025-08-31 07:00:00', 'actual_check_in': '2025-08-31 06:39:11', 'check_out': '2025-09-01 05:00:00', 'actual_check_out': False, 'status': 'allot', 'note': 'Limited Time Offer. Price includes 13% discount!\n Payment: ota_handle_payment', 'booking_id': 33699, 'booking_sequence_id': 'B32570', 'partner_id': 70845, 'partner_name': 'Nguyen Tuan Anh', 'gender': 'male', 'booking_line_guest_ids': [61437], 'medium_id': 17, 'medium_name': 'Agoda', 'source_id': 18, 'source_name': 'SO - OTA', 'campaign_id': None, 'campaign_name': None, 'cms_booking_id': 'AG64861756617258N3402', 'cms_ota_id': '1645563773', 'cms_booking_source': 'AGO', 'partner_identification': False, 'group_master_name': None, 'labels': [], 'hotel_travel_agency_name': 'Agoda', 'hotel_travel_agency_id': 4, 'create_date': '2025-08-31 05:14:20', 'group_id': 70845, 'group_master': None, 'room_status': {'is_clean': True, 'is_occupied': True}, 'surveys': {'is_checkin': False, 'is_checkout': False}, 'is_foc': False, 'reason_approve_by': False, 'foc_level': False, 'cancelled_at': False, 'room_no': '202', 'pricelist_id': 9, 'pricelist_name': 'OTA', 'room_is_clean': True, 'room_is_occupied': True, 'survey_is_checkin': False, 'survey_is_checkout': False}, {'booking_line_id': 43495, 'booking_line_sequence_id': 'BL41144', 'check_in_date': '2025-08-31', 'check_out_date': '2025-09-02', 'room_id': 9164, 'room_name': 'S.STD (302)', 'room_type_id': 9019, 'room_type_name': 'S.STD', 'original_room_type_name': 'S.STD', 'display_room_type_name': 'Super Standard', 'attributes': {'room_no': '302'}, 'price': 999000.0, 'booking_days': 2, 'paid_amount': 0.0, 'pricelist': None, 'sale_order_name': None, 'adult': 2, 'child': 0, 'subtotal_price': 1998000.0, 'total_price': 1998000.0, 'cancel_price': 0.0, 'cancel_reason': False, 'balance': 0.0, 'remain_amount': 1998000.0, 'check_in': '2025-08-31 07:00:00', 'actual_check_in': False, 'check_out': '2025-09-02 05:00:00', 'actual_check_out': False, 'status': 'initial', 'note': 'Đã báo pt in sớm 12h-13h30 là 330k\n13h khách qua thanh toán tại quầy\nPOA', 'booking_id': 33689, 'booking_sequence_id': 'B32560', 'partner_id': 70324, 'partner_name': 'Nguyễn Duy Quang', 'gender': 'male', 'booking_line_guest_ids': [61425, 61451], 'medium_id': 29, 'medium_name': 'zalo', 'source_id': 16, 'source_name': 'SO - FIT', 'campaign_id': None, 'campaign_name': None, 'cms_booking_id': False, 'cms_ota_id': False, 'cms_booking_source': False, 'partner_identification': False, 'group_master_name': None, 'labels': [], 'hotel_travel_agency_name': 'Zalo', 'hotel_travel_agency_id': 74, 'create_date': '2025-08-31 04:02:02', 'group_id': 70835, 'group_master': None, 'room_status': {'is_clean': True, 'is_occupied': False}, 'surveys': {'is_checkin': False, 'is_checkout': False}, 'is_foc': False, 'reason_approve_by': False, 'foc_level': False, 'cancelled_at': False, 'room_no': '302', 'pricelist_id': '', 'pricelist_name': '', 'room_is_clean': True, 'room_is_occupied': False, 'survey_is_checkin': False, 'survey_is_checkout': False}]
# [OK] KIN WANDER TAN QUY (id=5) → 0 records
# [OK] KIN WANDER TAN PHONG, THE MOONAGE (id=6) → 13 records
#   sample: [{'booking_line_id': 43504, 'booking_line_sequence_id': 'BL41153', 'check_in_date': '2025-08-31', 'check_out_date': '2025-09-01', 'room_id': 10970, 'room_name': 'DLX (302)', 'room_type_id': 10898, 'room_type_name': 'DLX', 'original_room_type_name': 'DLX', 'display_room_type_name': 'Deluxe City View', 'attributes': {'room_no': '302'}, 'price': 1096875.0, 'booking_days': 1, 'paid_amount': 0.0, 'pricelist': {'id': 9, 'name': 'OTA'}, 'sale_order_name': None, 'adult': 1, 'child': 0, 'subtotal_price': 1096875.0, 'total_price': 1096875.0, 'cancel_price': 0.0, 'cancel_reason': False, 'balance': 0.0, 'remain_amount': 1096875.0, 'check_in': '2025-08-31 07:00:00', 'actual_check_in': '2025-08-31 07:29:58', 'check_out': '2025-09-01 05:00:00', 'actual_check_out': False, 'status': 'allot', 'note': 'Limited Time Offer. Price includes 13% discount!\n Payment: ota_handle_payment', 'booking_id': 33698, 'booking_sequence_id': 'B32569', 'partner_id': 69640, 'partner_name': 'Mingquan Zuo', 'gender': 'male', 'booking_line_guest_ids': [61436], 'medium_id': 17, 'medium_name': 'Agoda', 'source_id': 18, 'source_name': 'SO - OTA', 'campaign_id': None, 'campaign_name': None, 'cms_booking_id': 'AGB0861756616542N3402', 'cms_ota_id': '1645560702', 'cms_booking_source': 'AGO', 'partner_identification': False, 'group_master_name': None, 'labels': [], 'hotel_travel_agency_name': 'Agoda', 'hotel_travel_agency_id': 4, 'create_date': '2025-08-31 05:02:24', 'group_id': 70844, 'group_master': None, 'room_status': {'is_clean': True, 'is_occupied': True}, 'surveys': {'is_checkin': False, 'is_checkout': False}, 'is_foc': False, 'reason_approve_by': False, 'foc_level': False, 'cancelled_at': False, 'room_no': '302', 'pricelist_id': 9, 'pricelist_name': 'OTA', 'room_is_clean': True, 'room_is_occupied': True, 'survey_is_checkin': False, 'survey_is_checkout': False}, {'booking_line_id': 43499, 'booking_line_sequence_id': 'BL41148', 'check_in_date': '2025-08-31', 'check_out_date': '2025-09-01', 'room_id': 14489, 'room_name': 'STD2 (103)', 'room_type_id': 14093, 'room_type_name': 'STD2', 'original_room_type_name': 'STD2', 'display_room_type_name': 'Standard City View', 'attributes': {'room_no': '103'}, 'price': 899000.0, 'booking_days': 1, 'paid_amount': 0.0, 'pricelist': None, 'sale_order_name': None, 'adult': 1, 'child': 0, 'subtotal_price': 899000.0, 'total_price': 899000.0, 'cancel_price': 0.0, 'cancel_reason': False, 'balance': -899000.0, 'remain_amount': 0.0, 'check_in': '2025-08-31 07:00:00', 'actual_check_in': '2025-08-31 06:42:15', 'check_out': '2025-09-01 05:00:00', 'actual_check_out': False, 'status': 'allot', 'note': 'khách ở dài hạn từ 14/8 hỗ trợ giá FIT\nbk nối R203 #33613 - 43402', 'booking_id': 33693, 'booking_sequence_id': 'B32564', 'partner_id': 67235, 'partner_name': 'Nguyễn Đăng Trưởng', 'gender': 'male', 'booking_line_guest_ids': [61429], 'medium_id': 15, 'medium_name': 'Walk - In', 'source_id': 20, 'source_name': 'SO - Walk-in', 'campaign_id': None, 'campaign_name': None, 'cms_booking_id': False, 'cms_ota_id': False, 'cms_booking_source': False, 'partner_identification': '030096012608', 'group_master_name': None, 'labels': [], 'hotel_travel_agency_name': 'Walkin', 'hotel_travel_agency_id': 73, 'create_date': '2025-08-31 04:21:43', 'group_id': 67235, 'group_master': None, 'room_status': {'is_clean': True, 'is_occupied': True}, 'surveys': {'is_checkin': False, 'is_checkout': False}, 'is_foc': False, 'reason_approve_by': False, 'foc_level': False, 'cancelled_at': False, 'room_no': '103', 'pricelist_id': '', 'pricelist_name': '', 'room_is_clean': True, 'room_is_occupied': True, 'survey_is_checkin': False, 'survey_is_checkout': False}]
# [OK] KIN WANDER TRUNG SON (id=7) → 3 records
#   sample: [{'booking_line_id': 43513, 'booking_line_sequence_id': 'BL41162', 'check_in_date': '2025-08-31', 'check_out_date': '2025-09-01', 'room_id': 11132, 'room_name': 'STD (101)', 'room_type_id': 11037, 'room_type_name': 'STD', 'original_room_type_name': 'STD', 'display_room_type_name': 'Standard', 'attributes': {'room_no': '101'}, 'price': 809000.0, 'booking_days': 1, 'paid_amount': 0.0, 'pricelist': {'id': 9, 'name': 'OTA'}, 'sale_order_name': None, 'adult': 1, 'child': 0, 'subtotal_price': 809000.0, 'total_price': 809000.0, 'cancel_price': 0.0, 'cancel_reason': False, 'balance': 0.0, 'remain_amount': 809000.0, 'check_in': '2025-08-31 07:00:00', 'actual_check_in': '2025-08-31 08:21:19', 'check_out': '2025-09-01 05:00:00', 'actual_check_out': False, 'status': 'allot', 'note': '\n Payment: ota_handle_payment\nXuấy hóa đơn VAT\nTên công ty: CÔNG TY TNHH OHMYHOTEL&CO VN\n\nMã số thuế: 0314937097 Email: accounting.vn@ohmyhotel.com\n\nĐịa chỉ: Khu F7-BCD, Tầng 7, Tòa nhà Mach, 127 Ung Văn Khiêm, Phường Thạnh Mỹ Tây, TP.Hồ Chí Minh', 'booking_id': 33707, 'booking_sequence_id': 'B32578', 'partner_id': 70417, 'partner_name': 'Đào Nguyễn Đăng Khoa', 'gender': 'male', 'booking_line_guest_ids': [61461], 'medium_id': 32, 'medium_name': 'Ohmyhotel', 'source_id': 18, 'source_name': 'SO - OTA', 'campaign_id': None, 'campaign_name': None, 'cms_booking_id': 'OT85161756627744', 'cms_ota_id': 'K25083111152H01', 'cms_booking_source': 'OMHT', 'partner_identification': False, 'group_master_name': None, 'labels': [], 'hotel_travel_agency_name': 'Ohmyhotel', 'hotel_travel_agency_id': 16, 'create_date': '2025-08-31 08:09:06', 'group_id': 70872, 'group_master': None, 'room_status': {'is_clean': True, 'is_occupied': True}, 'surveys': {'is_checkin': False, 'is_checkout': False}, 'is_foc': False, 'reason_approve_by': False, 'foc_level': False, 'cancelled_at': False, 'room_no': '101', 'pricelist_id': 9, 'pricelist_name': 'OTA', 'room_is_clean': True, 'room_is_occupied': True, 'survey_is_checkin': False, 'survey_is_checkout': False}, {'booking_line_id': 43432, 'booking_line_sequence_id': 'BL41081', 'check_in_date': '2025-08-31', 'check_out_date': '2025-09-01', 'room_id': 11132, 'room_name': 'STD (101)', 'room_type_id': 11037, 'room_type_name': 'STD', 'original_room_type_name': 'STD', 'display_room_type_name': 'Standard', 'attributes': {'room_no': '101'}, 'price': 999000.0, 'booking_days': 1, 'paid_amount': 0.0, 'pricelist': None, 'sale_order_name': None, 'adult': 2, 'child': 1, 'subtotal_price': 999000.0, 'total_price': 999000.0, 'cancel_price': 0.0, 'cancel_reason': 'thay đỏi lịch trình', 'balance': 0.0, 'remain_amount': 999000.0, 'check_in': '2025-08-31 07:00:00', 'actual_check_in': False, 'check_out': '2025-09-01 05:00:00', 'actual_check_out': False, 'status': 'cancel', 'note': False, 'booking_id': 33640, 'booking_sequence_id': 'B32511', 'partner_id': 70746, 'partner_name': 'Duy Tân', 'gender': 'male', 'booking_line_guest_ids': [61319], 'medium_id': 15, 'medium_name': 'Walk - In', 'source_id': 20, 'source_name': 'SO - Walk-in', 'campaign_id': None, 'campaign_name': None, 'cms_booking_id': False, 'cms_ota_id': False, 'cms_booking_source': False, 'partner_identification': False, 'group_master_name': None, 'labels': [], 'hotel_travel_agency_name': 'Walkin', 'hotel_travel_agency_id': 73, 'create_date': '2025-08-30 09:14:19', 'group_id': 70746, 'group_master': None, 'room_status': {'is_clean': True, 'is_occupied': True}, 'surveys': {'is_checkin': False, 'is_checkout': False}, 'is_foc': False, 'reason_approve_by': False, 'foc_level': False, 'cancelled_at': '2025-08-30 10:23:53', 'room_no': '101', 'pricelist_id': '', 'pricelist_name': '', 'room_is_clean': True, 'room_is_occupied': True, 'survey_is_checkin': False, 'survey_is_checkout': False}]
# [FAIL] Branch 8 (id=8) → HTTP 401 for https://api-pms.kinliving.vn/api/bookings
# [OK] KIN HOTEL CENTRAL PARK (id=9) → 9 records
#   sample: [{'booking_line_id': 43514, 'booking_line_sequence_id': 'BL41163', 'check_in_date': '2025-08-31', 'check_out_date': '2025-09-01', 'room_id': 14157, 'room_name': 'DLXDNW (304)', 'room_type_id': 13814, 'room_type_name': 'DLXDNW', 'original_room_type_name': 'DLXDNW', 'display_room_type_name': 'DELUXE DOUBLE NO WINDOW', 'attributes': {'room_no': '304'}, 'price': 901056.0, 'booking_days': 1, 'paid_amount': 0.0, 'pricelist': {'id': 9, 'name': 'OTA'}, 'sale_order_name': None, 'adult': 2, 'child': 0, 'subtotal_price': 901056.0, 'total_price': 901056.0, 'cancel_price': 0.0, 'cancel_reason': False, 'balance': 0.0, 'remain_amount': 901056.0, 'check_in': '2025-08-31 07:00:00', 'actual_check_in': '2025-08-31 09:02:55', 'check_out': '2025-09-01 05:00:00', 'actual_check_out': False, 'status': 'allot', 'note': 'Limited Time Offer. Price includes 41% discount!\n Payment: ota_handle_payment', 'booking_id': 33708, 'booking_sequence_id': 'B32579', 'partner_id': 70873, 'partner_name': 'DEFA YANG', 'gender': 'male', 'booking_line_guest_ids': [61462, 61474], 'medium_id': 17, 'medium_name': 'Agoda', 'source_id': 18, 'source_name': 'SO - OTA', 'campaign_id': None, 'campaign_name': None, 'cms_booking_id': 'AG679E1756628665N3404', 'cms_ota_id': '1645617442', 'cms_booking_source': 'AGO', 'partner_identification': 'EB028797I', 'group_master_name': None, 'labels': [], 'hotel_travel_agency_name': 'Agoda', 'hotel_travel_agency_id': 4, 'create_date': '2025-08-31 08:24:27', 'group_id': 70873, 'group_master': None, 'room_status': {'is_clean': True, 'is_occupied': True}, 'surveys': {'is_checkin': False, 'is_checkout': False}, 'is_foc': False, 'reason_approve_by': False, 'foc_level': False, 'cancelled_at': False, 'room_no': '304', 'pricelist_id': 9, 'pricelist_name': 'OTA', 'room_is_clean': True, 'room_is_occupied': True, 'survey_is_checkin': False, 'survey_is_checkout': False}, {'booking_line_id': 43470, 'booking_line_sequence_id': 'BL41119', 'check_in_date': '2025-08-31', 'check_out_date': '2025-08-31', 'room_id': 14188, 'room_name': 'DLXDNW (1406)', 'room_type_id': 13814, 'room_type_name': 'DLXDNW', 'original_room_type_name': 'DLXDNW', 'display_room_type_name': 'DELUXE DOUBLE NO WINDOW', 'attributes': {'room_no': '1406'}, 'price': 1300000.0, 'booking_days': 1, 'paid_amount': 0.0, 'pricelist': None, 'sale_order_name': None, 'adult': 2, 'child': 0, 'subtotal_price': 1300000.0, 'total_price': 1300000.0, 'cancel_price': 0.0, 'cancel_reason': False, 'balance': 0.0, 'remain_amount': 0.0, 'check_in': '2025-08-30 19:00:00', 'actual_check_in': '2025-08-30 18:30:33', 'check_out': '2025-08-31 05:00:00', 'actual_check_out': '2025-08-30 22:58:52', 'status': 'checkout', 'note': 'DLXNW   BF  1300.000 ', 'booking_id': 33674, 'booking_sequence_id': 'B32545', 'partner_id': 70814, 'partner_name': 'HUYNH CAM TU MI ', 'gender': 'male', 'booking_line_guest_ids': [61392, 61393], 'medium_id': 15, 'medium_name': 'Walk - In', 'source_id': 20, 'source_name': 'SO - Walk-in', 'campaign_id': None, 'campaign_name': None, 'cms_booking_id': False, 'cms_ota_id': False, 'cms_booking_source': False, 'partner_identification': '087302000274', 'group_master_name': None, 'labels': [], 'hotel_travel_agency_name': 'Walkin', 'hotel_travel_agency_id': 73, 'create_date': '2025-08-30 18:26:23', 'group_id': 70814, 'group_master': None, 'room_status': {'is_clean': True, 'is_occupied': False}, 'surveys': {'is_checkin': False, 'is_checkout': False}, 'is_foc': False, 'reason_approve_by': False, 'foc_level': False, 'cancelled_at': False, 'room_no': '1406', 'pricelist_id': '', 'pricelist_name': '', 'room_is_clean': True, 'room_is_occupied': False, 'survey_is_checkin': False, 'survey_is_checkout': False}]
# [FAIL] KIN HOTEL LY TU TRONG (id=10) → HTTP 403 for https://api-pms.kinliving.vn/api/bookings
#
# DONE: 6/10 branches OK
